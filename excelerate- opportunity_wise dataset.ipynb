# %% [markdown]
#  ## Opportunity Wise - Data cleaning for Excelerate week 1

# %% [markdown]
# the dataset focuses on non-identifying user information related to learners who have engaged with specific opportunities on Excelerate.
#
# profile id             unique identification identifier
# opportunity Name       name of the opportunity(experience) they participated in
# Opportunity category   the category of experience they participated in
# gender                 gender of the student
# city                   given city of the student
# state
# country                given country of the student
# current student status
# current/intended major
# status description

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %matplotlib inline

# %%
opportunity_wise_df = pd.read_excel('Opportunity Wise Data2.xlsx')
users_data_df = pd.read_excel('UserData (2).xlsx')

# %%
opportunity_wise_df.head(4)
# Out:
#                              Profile Id                  Opportunity Id  \
# 0  31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1  36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2  8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3  a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
#
#                               Opportunity Name Opportunity Category  \
# 0  Statement of Purpose (SOP) Writing Workshop                Event
# 1  Statement of Purpose (SOP) Writing Workshop                Event
# 2  Statement of Purpose (SOP) Writing Workshop                Event
# 3  Statement of Purpose (SOP) Writing Workshop                Event
#
#      Opportunity End Date  Gender       City           State      Country  \
# 0  Jan 05, 2023, 18:58:39    Male      Dhaka           Savar   Bangladesh
# 1  Jan 05, 2023, 18:58:39  Female   Amritsar          Punjab  Afghanistan
# ...

# %%
opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  object
#  5   Gender                    20321 non-null  object
#  6   City                      20321 non-null  object
#  7   State                     20316 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20321 non-null  object
#  11  Current Student Status    20321 non-null  object
#  12  Current/Intended Major    20318 non-null  object
# ...

# %%
opportunity_wise_df.shape
# Out:
# (20322, 21)

# %%
opportunity_wise_df.columns
# Out:
# Index(['Profile Id', 'Opportunity Id', 'Opportunity Name',
#        'Opportunity Category', 'Opportunity End Date', 'Gender', 'City',
#        'State', 'Country', 'Zip Code', 'Graduation Date(YYYY MM)',
#        'Current Student Status', 'Current/Intended Major',
#        'Status Description', 'Apply Date', 'Opportunity Start Date',
#        'Reward Amount', 'Badge Id', 'Badge Name', 'Skill Points Earned',
#        'Skills Earned'],
#       dtype='object')

# %%
opportunity_wise_df.isna().sum()
# Out:
# Profile Id                      0
# Opportunity Id                  0
# Opportunity Name                0
# Opportunity Category            0
# Opportunity End Date            0
# Gender                          1
# City                            1
# State                           6
# Country                         0
# Zip Code                        2
# Graduation Date(YYYY MM)        1
# Current Student Status          1
# Current/Intended Major          4
# Status Description              0
# Apply Date                      0
# Opportunity Start Date        804
# Reward Amount               17801
# Badge Id                    17801
# Badge Name                  17801
# Skill Points Earned         17801
# Skills Earned               17801
# dtype: int64

# %%
missing_value_count = opportunity_wise_df.isnull().sum()

# %%
missing_value_count
# Out:
# Profile Id                      0
# Opportunity Id                  0
# Opportunity Name                0
# Opportunity Category            0
# Opportunity End Date            0
# Gender                          1
# City                            1
# State                           6
# Country                         0
# Zip Code                        2
# Graduation Date(YYYY MM)        1
# Current Student Status          1
# Current/Intended Major          4
# Status Description              0
# Apply Date                      0
# Opportunity Start Date        804
# Reward Amount               17801
# Badge Id                    17801
# Badge Name                  17801
# Skill Points Earned         17801
# Skills Earned               17801
# dtype: int64

# %%
missing_value_count[50:]
# Out:
# Series([], dtype: int64)

# %%
missing_value_count
# Out:
# Profile Id                      0
# Opportunity Id                  0
# Opportunity Name                0
# Opportunity Category            0
# Opportunity End Date            0
# Gender                          1
# City                            1
# State                           6
# Country                         0
# Zip Code                        2
# Graduation Date(YYYY MM)        1
# Current Student Status          1
# Current/Intended Major          4
# Status Description              0
# Apply Date                      0
# Opportunity Start Date        804
# Reward Amount               17801
# Badge Id                    17801
# Badge Name                  17801
# Skill Points Earned         17801
# Skills Earned               17801
# dtype: int64

# %%
total_cells_missing = np.product(opportunity_wise_df.shape)
total_missing = missing_value_count.sum()
total_missing
# Out:
# 89825

# %%
percent_of_missing_values = (total_missing/total_cells_missing) * 100
print(percent_of_missing_values)
# Out:
# 21.04803145547167

# %%
opportunity_wise_df.describe()
# Out:
#        Reward Amount  Skill Points Earned
# count    2521.000000          2521.000000
# mean     1081.261404          1186.964697
# std       927.251398           399.172150
# min        50.000000            10.000000
# 25%       500.000000          1182.000000
# 50%       500.000000          1182.000000
# 75%      2500.000000          1182.000000
# max      2500.000000          1776.000000

# %%
opportunity_wise_df['Reward Amount'].fillna('0', inplace = True)
opportunity_wise_df
# Out:
#                                  Profile Id                  Opportunity Id  \
# 0      31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1      36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2      8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3      a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4      c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
# ...                                     ...                             ...
# 20317  f386224b-4b64-4d70-a6c5-8d90e3653925  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20318  f398b382-ac7a-4b14-8f76-cd41a51b1459  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20319  f476e230-266d-491b-a693-f3f3bccac7d6  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20320  f92acfd4-3888-447a-a6dd-f996544eebbb  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20321  fdccf84d-6011-4048-ad8d-73df5e7c431e  00000000-101Y-HSX2-0DFJ-QCKQBR
#
# ...

# %%
opportunity_wise_df['Badge Name'].fillna("Not specified", inplace=True)
opportunity_wise_df['Skills Earned'].fillna("Not specified", inplace=True)
opportunity_wise_df['State'].fillna("Not specified", inplace=True)
opportunity_wise_df['Gender'].fillna("Not specified", inplace=True)
opportunity_wise_df['City'].fillna("Not specified", inplace=True)
opportunity_wise_df['Current/Intended Major'].fillna("Not specified", inplace=True)
opportunity_wise_df['Current Student Status'].fillna("Not specified", inplace=True)

# %%
opportunity_wise_df['Skill Points Earned'].fillna('0', inplace = True)
opportunity_wise_df
# Out:
#                                  Profile Id                  Opportunity Id  \
# 0      31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1      36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2      8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3      a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4      c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
# ...                                     ...                             ...
# 20317  f386224b-4b64-4d70-a6c5-8d90e3653925  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20318  f398b382-ac7a-4b14-8f76-cd41a51b1459  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20319  f476e230-266d-491b-a693-f3f3bccac7d6  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20320  f92acfd4-3888-447a-a6dd-f996544eebbb  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20321  fdccf84d-6011-4048-ad8d-73df5e7c431e  00000000-101Y-HSX2-0DFJ-QCKQBR
#
# ...

# %%
opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  object
#  5   Gender                    20322 non-null  object
#  6   City                      20322 non-null  object
#  7   State                     20322 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20321 non-null  object
#  11  Current Student Status    20322 non-null  object
#  12  Current/Intended Major    20322 non-null  object
# ...

# %%
opportunity_wise_df.isnull().sum()
# Out:
# Profile Id                      0
# Opportunity Id                  0
# Opportunity Name                0
# Opportunity Category            0
# Opportunity End Date            0
# Gender                          0
# City                            0
# State                           0
# Country                         0
# Zip Code                        2
# Graduation Date(YYYY MM)        1
# Current Student Status          0
# Current/Intended Major          0
# Status Description              0
# Apply Date                      0
# Opportunity Start Date        804
# Reward Amount                   0
# Badge Id                    17801
# Badge Name                      0
# Skill Points Earned             0
# Skills Earned                   0
# dtype: int64

# %%
opportunity_wise_df.drop(['Badge Id'], axis=1)
# Out:
#                                  Profile Id                  Opportunity Id  \
# 0      31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1      36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2      8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3      a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4      c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
# ...                                     ...                             ...
# 20317  f386224b-4b64-4d70-a6c5-8d90e3653925  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20318  f398b382-ac7a-4b14-8f76-cd41a51b1459  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20319  f476e230-266d-491b-a693-f3f3bccac7d6  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20320  f92acfd4-3888-447a-a6dd-f996544eebbb  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20321  fdccf84d-6011-4048-ad8d-73df5e7c431e  00000000-101Y-HSX2-0DFJ-QCKQBR
#
# ...

# %%
opportunity_wise_df.drop(columns=['Badge Id'], inplace=True)

# %%
opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  datetime64[ns]
#  5   Gender                    20322 non-null  object
#  6   City                      20322 non-null  object
#  7   State                     20322 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20309 non-null  datetime64[ns]
#  11  Current Student Status    20322 non-null  object
#  12  Current/Intended Major    20322 non-null  object
# ...

# %%
opportunity_wise_df.isnull().sum()
# Out:
# Profile Id                    0
# Opportunity Id                0
# Opportunity Name              0
# Opportunity Category          0
# Opportunity End Date          0
# Gender                        0
# City                          0
# State                         0
# Country                       0
# Zip Code                      2
# Graduation Date(YYYY MM)     13
# Current Student Status        0
# Current/Intended Major        0
# Status Description            0
# Apply Date                  463
# Opportunity Start Date      804
# Reward Amount                 0
# Badge Name                    0
# Skill Points Earned           0
# Skills Earned                 0
# dtype: int64

# %%
opportunity_wise_df.drop(['Badge Id'], axis=1)
# Out:
#                                  Profile Id                  Opportunity Id  \
# 0      31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1      36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2      8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3      a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4      c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
# ...                                     ...                             ...
# 20317  f386224b-4b64-4d70-a6c5-8d90e3653925  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20318  f398b382-ac7a-4b14-8f76-cd41a51b1459  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20319  f476e230-266d-491b-a693-f3f3bccac7d6  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20320  f92acfd4-3888-447a-a6dd-f996544eebbb  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20321  fdccf84d-6011-4048-ad8d-73df5e7c431e  00000000-101Y-HSX2-0DFJ-QCKQBR
#
# ...

# %%
opportunity_wise_df.describe()
# Out:
#                                   Profile Id                  Opportunity Id  \
# count                                  20322                           20322
# unique                                 11481                              33
# top     18e1e6bc-fada-4b09-bf52-ab45daf318f4  00000000-0GWQ-AXC5-X45C-2MHJ28
# freq                                      22                            5687
#
#           Opportunity Name Opportunity Category    Opportunity End Date  \
# count                20322                20322                   20322
# unique                  33                    5                      29
# top     Data Visualization           Internship  Jan 01, 2024, 03:30:46
# freq                  5687                15360                   14938
#
#        Gender         City     State Country  Zip Code  ...  \
# count   20322        20322     20322   20322     20320  ...
# unique      5         3142      1372     108      5190  ...
# ...

# %%
opportunity_wise_df['Reward Amount'] = opportunity_wise_df['Reward Amount'].astype(int)
opportunity_wise_df['Skill Points Earned'] = opportunity_wise_df['Skill Points Earned'].astype(int)

opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  object
#  5   Gender                    20322 non-null  object
#  6   City                      20322 non-null  object
#  7   State                     20322 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20321 non-null  object
#  11  Current Student Status    20322 non-null  object
#  12  Current/Intended Major    20322 non-null  object
# ...

# %%
opportunity_wise_df.columns
# Out:
# Index(['Profile Id', 'Opportunity Id', 'Opportunity Name',
#        'Opportunity Category', 'Opportunity End Date', 'Gender', 'City',
#        'State', 'Country', 'Zip Code', 'Graduation Date(YYYY MM)',
#        'Current Student Status', 'Current/Intended Major',
#        'Status Description', 'Apply Date', 'Opportunity Start Date',
#        'Reward Amount', 'Badge Id', 'Badge Name', 'Skill Points Earned',
#        'Skills Earned'],
#       dtype='object')

# %%
opportunity_wise_df.drop(['Badge Id'], axis=1)
# Out:
#                                  Profile Id                  Opportunity Id  \
# 0      31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1      36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2      8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3      a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4      c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
# ...                                     ...                             ...
# 20317  f386224b-4b64-4d70-a6c5-8d90e3653925  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20318  f398b382-ac7a-4b14-8f76-cd41a51b1459  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20319  f476e230-266d-491b-a693-f3f3bccac7d6  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20320  f92acfd4-3888-447a-a6dd-f996544eebbb  00000000-101Y-HSX2-0DFJ-QCKQBR
# 20321  fdccf84d-6011-4048-ad8d-73df5e7c431e  00000000-101Y-HSX2-0DFJ-QCKQBR
#
# ...

# %%
opportunity_wise_df[['Date', 'Year', 'Time']] = opportunity_wise_df['Opportunity End Date'].str.split(',', expand=True)

# %%
opportunity_wise_df.head(2)
# Out:
#                              Profile Id                  Opportunity Id  \
# 0  31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1  36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
#
#                               Opportunity Name Opportunity Category  \
# 0  Statement of Purpose (SOP) Writing Workshop                Event
# 1  Statement of Purpose (SOP) Writing Workshop                Event
#
#      Opportunity End Date  Gender      City   State      Country Zip Code  \
# 0  Jan 05, 2023, 18:58:39    Male     Dhaka   Savar   Bangladesh     1342
# 1  Jan 05, 2023, 18:58:39  Female  Amritsar  Punjab  Afghanistan   123242
#
#    ... Current Student Status Current/Intended Major Status Description  \
# 0  ...    High School Student           Data Science        Not Started
# 1  ...  Undergraduate Student            Otheraassss      Rewards Award
#
#                Apply Date  Opportunity Start Date Reward Amount  \
# ...

# %%
opportunity_wise_df['Opportunity End Date'] = pd.to_datetime(opportunity_wise_df['Opportunity End Date'])
opportunity_wise_df['Graduation Date(YYYY MM)'] = pd.to_datetime(opportunity_wise_df['Graduation Date(YYYY MM)'], errors= 'coerce')
opportunity_wise_df['Apply Date'] = pd.to_datetime(opportunity_wise_df['Apply Date'])
opportunity_wise_df['Opportunity Start Date'] = pd.to_datetime(opportunity_wise_df['Opportunity Start Date'])

# %%
opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  datetime64[ns]
#  5   Gender                    20322 non-null  object
#  6   City                      20322 non-null  object
#  7   State                     20322 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20309 non-null  datetime64[ns]
#  11  Current Student Status    20322 non-null  object
#  12  Current/Intended Major    20322 non-null  object
# ...

# %%
opportunity_wise_df.describe()
# Out:
#        Reward Amount  Skill Points Earned
# count   20322.000000         20322.000000
# mean      134.133451           147.246236
# std       483.394958           415.766356
# min         0.000000             0.000000
# 25%         0.000000             0.000000
# 50%         0.000000             0.000000
# 75%         0.000000             0.000000
# max      2500.000000          1776.000000

# %%
opportunity_wise_df['Reward Amount'].mean()
# Out:
# 134.13345143194567

# %%
opportunity_wise_df['Reward Amount'].median()
# Out:
# 0.0

# %%
opportunity_wise_df.describe()
# Out:
#        Reward Amount  Skill Points Earned
# count   20322.000000         20322.000000
# mean      134.133451           147.246236
# std       483.394958           415.766356
# min         0.000000             0.000000
# 25%         0.000000             0.000000
# 50%         0.000000             0.000000
# 75%         0.000000             0.000000
# max      2500.000000          1776.000000

# %% [markdown]
# ## EDA - exploration _opportunity_wise dataset

# %%
opportunity_wise_df['Badge Name'].fillna("Not specified", inplace=True)
opportunity_wise_df['Skills Earned'].fillna("Not specified", inplace=True)
opportunity_wise_df['State'].fillna("Not specified", inplace=True)
opportunity_wise_df['Gender'].fillna("Not specified", inplace=True)
opportunity_wise_df['City'].fillna("Not specified", inplace=True)
opportunity_wise_df['Current/Intended Major'].fillna("Not specified", inplace=True)
opportunity_wise_df['Current Student Status'].fillna("Not specified", inplace=True)

# %%
opportunity_wise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20322 entries, 0 to 20321
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Profile Id                20322 non-null  object
#  1   Opportunity Id            20322 non-null  object
#  2   Opportunity Name          20322 non-null  object
#  3   Opportunity Category      20322 non-null  object
#  4   Opportunity End Date      20322 non-null  datetime64[ns]
#  5   Gender                    20322 non-null  object
#  6   City                      20322 non-null  object
#  7   State                     20322 non-null  object
#  8   Country                   20322 non-null  object
#  9   Zip Code                  20320 non-null  object
#  10  Graduation Date(YYYY MM)  20309 non-null  datetime64[ns]
#  11  Current Student Status    20322 non-null  object
#  12  Current/Intended Major    20322 non-null  object
# ...

# %%
opportunity_wise_df['Opportunity Name'].value_counts()
# Out:
# Data Visualization                                                   5687
# Project Management                                                   3908
# Digital Marketing                                                    2480
# Health Care Management                                               1548
# Innovation & Entrepreneurship                                        1315
# Career Essentials: Getting Started with Your Professional Journey    1241
# Linked Up: The LinkedIn Makeover Workshop                             519
# CPR/AED Certification                                                 460
# Epidemiology Training Internship                                      422
# Money Matters: A Personal Finance Workshop                            352
# Leadership Launchpad                                                  332
# Mental Health First Aid Workshop                                      211
# The Brand Booster Challenge                                           186
# ...

# %%
opportunity_wise_df['Opportunity Name'].hist()
# Out:
# <Axes: >

# %%
filtered_opportunity_name = opportunity_wise_df['Opportunity Name'].value_counts()
Top_opportunity = filtered_opportunity_name.head(5)
print('top_5_opportunity_name is: ', Top_opportunity )
# Out:
# top_5_opportunity_name is:  Data Visualization               5687
# Project Management               3908
# Digital Marketing                2480
# Health Care Management           1548
# Innovation & Entrepreneurship    1315
# Name: Opportunity Name, dtype: int64

# %%
# Plotting the top 5 most common opportunity names
plt.figure(figsize=(10, 6))
Top_opportunity.plot(kind='bar', color='teal')
plt.title('Top 5 Most Common Opportunity_name')
plt.xlabel('Opportunity Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
Least_opportunity = filtered_opportunity_name.tail(5)
print('top_5_opportunity_name is: ', Least_opportunity )

# Plotting the top 5 least common opportunity names
plt.figure(figsize=(10, 6))
Least_opportunity.plot(kind='bar', color='brown')
plt.title('Least Common Opportunity_name')
plt.xlabel('Opportunity Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
# Out:
# top_5_opportunity_name is:  Mental and Physical Health Session                    30
# Jump Start: Developing your Emotional Intelligence    29
# Life Beyond Saint Louis University's Campus           22
# Statement of Purpose (SOP) Writing Workshop            5
# Upload Your First Year Transcript                      4
# Name: Opportunity Name, dtype: int64

# %%
opportunity_wise_df['Opportunity Category'].hist()
# Out:
# <Axes: >

# %%
opportunity_wise_df['Gender'].hist()
# Out:
# <Axes: >

# %%
opportunity_wise_df['Country'].value_counts()
# Out:
# India                   9132
# United States           3856
# Nigeria                 3351
# Pakistan                1053
# Ghana                    898
#                         ...
# Virgin Islands, U.S.       1
# Aruba                      1
# Norway                     1
# Burkina Faso               1
# Senegal                    1
# Name: Country, Length: 108, dtype: int64

# %%
filtered_Country = opportunity_wise_df['Country'].value_counts()
Top_Country = filtered_Country.head(10)
print('top_10_Country is: ', Top_Country )

# Plotting the top 5 most common opportunity names
plt.figure(figsize=(10, 6))
Top_Country.plot(kind='bar', color='blue')
plt.title('Top 5 Most Common Opportunity_name')
plt.xlabel('Opportunity Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()
# Out:
# top_10_Country is:  India            9132
# United States    3856
# Nigeria          3351
# Pakistan         1053
# Ghana             898
# Egypt             444
# Vietnam           176
# Kenya             155
# Bangladesh        145
# Nepal             113
# Name: Country, dtype: int64

# %%
opportunity_wise_df['Current Student Status'].hist()
# Out:
# <Axes: >

# %%
student_status = opportunity_wise_df['Current Student Status'].value_counts().hist()

# %%
# Plotting the student status
student_status = opportunity_wise_df['Current Student Status'].value_counts()
plt.figure(figsize=(10, 6))
plt.plot(data= student_status, kind='bar', color='blue')
plt.title('Top 5 Most Common Opportunity_name')
plt.xlabel('Opportunity Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
opportunity_wise_df['Current Student Status']

# %%
#plotting 
hot_tub_distribution = amenities_df['hot_tub'].value_counts()
pool_distribution = amenities_df['pool'].value_counts()

# Visualization
plt.figure(figsize=(12, 5))

# Plot for hot tub distribution
plt.subplot(1, 2, 1)
sns.barplot(x=hot_tub_distribution.index, y=hot_tub_distribution.values, palette="Blues_d")
plt.title('Hot Tubs Distribution')
plt.xlabel('Hot Tub Presence')
plt.ylabel('Count of Hot Tubs')
plt.xticks([0, 1], ['Absent', 'Present'])

# %%
street_name_filtered = geolocation_df[geolocation_df['street_name'] != "Not specified"]
filtered_street_name_counts = street_name_filtered['street_name'].value_counts()

common_street = geolocation_df['street_name'].value_counts().head(10)
print('common street is: ', common_street)

most_common_streets_filtered = filtered_street_name_counts.head(10)
print("Most Common Street Names (excluding 'Not specified'):\n", most_common_streets_filtered)

least_common_streets_filtered = filtered_street_name_counts.tail(10)
print("\nLeast Common Street Names (excluding 'Not specified'):\n", least_common_streets_filtered)

# %%
# Plotting the top 5 most common street names (excluding 'Street name is not specified')
plt.figure(figsize=(10, 6))
most_common_streets_filtered.plot(kind='bar', color='teal')
plt.title('Top 5 Most Common Street Names (Excluding Unspecified)')
plt.xlabel('Street Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Plotting the 5 least common street names (excluding 'Street name is not specified')
plt.figure(figsize=(10, 6))
least_common_streets_filtered.plot(kind='bar', color='orange')
plt.title('Top 5 Least Common Street Names (Excluding Unspecified)')
plt.xlabel('Street Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
hot_tub_distribution = amenities_df['hot_tub'].value_counts()
pool_distribution = amenities_df['pool'].value_counts()

# Visualization
plt.figure(figsize=(12, 5))

# Plot for hot tub distribution
plt.subplot(1, 2, 1)
sns.barplot(x=hot_tub_distribution.index, y=hot_tub_distribution.values, palette="Blues_d")
plt.title('Hot Tubs Distribution')
plt.xlabel('Hot Tub Presence')
plt.ylabel('Count of Hot Tubs')
plt.xticks([0, 1], ['Absent', 'Present'])

# %%
# Plot for pool distribution
plt.subplot(1, 2, 2)
sns.barplot(x=pool_distribution.index, y=pool_distribution.values, palette="Greens_d")
plt.title('Distribution of Pools')
plt.xlabel('Pool Presence')
plt.ylabel('Count of Pools')
plt.xticks([0, 1], ['Absent', 'Present'])

plt.tight_layout()
plt.show()

# %%
amenities_df['year'] = amenities_df['month'].str[:4]
amenities_df['quarter'] = pd.to_datetime(amenities_df['month']).dt.to_period('Q')

# Grouping data by quarter and calculating the sum for hot tubs and pools
quarterly_amenities = amenities_df.groupby(['year', 'quarter'])[['hot_tub', 'pool']].sum().reset_index()
# Re-plotting with adjusted tick angles

plt.figure(figsize=(14, 6))
# Plot for hot tub trends by quarter
plt.subplot(1, 2, 1)
sns.barplot(x='quarter', y='hot_tub', hue='year', data=quarterly_amenities, palette='Blues')
plt.title('Quarterly Trend of Hot Tub Presence')
plt.xlabel('Quarter')
plt.ylabel('Total Hot Tubs')
plt.xticks(rotation=45)  # Rotating ticks

# Plot for pool trends by quarter
plt.subplot(1, 2, 2)
sns.barplot(x='quarter', y='pool', hue='year', data=quarterly_amenities, palette='Oranges')
plt.title('Quarterly Trend of Pool Presence')
plt.xlabel('Quarter')
plt.ylabel('Total Pools')
plt.xticks(rotation=45)  # Rotating ticks

plt.tight_layout()
plt.show()

# %%
# Extracting only the relevant numerical columns for monthly trend analysis
numerical_columns = ['revenue', 'occupancy', 'nightly rate', 'lead time', 'length stay']

# Grouping data by month and calculating the mean for the selected numerical columns
monthly_trends_numerical = new_market_analysis.groupby(new_market_analysis['month'].dt.to_period('M'))[numerical_columns].mean()

# Visualization
plt.figure(figsize=(15, 6))

# Plot for monthly trend of revenue
plt.subplot(1, 2, 1)
monthly_trends_numerical['revenue'].plot(kind='line', marker='o', color='blue')
plt.title('Monthly Trend of Revenue')
plt.xlabel('Month')
plt.ylabel('Average Revenue')
plt.xticks(rotation=45)

# Plot for monthly trend of occupancy
plt.subplot(1, 2, 2)
monthly_trends_numerical['occupancy'].plot(kind='line', marker='o', color='green')
plt.title('Monthly Trend of Occupancy')
plt.xlabel('Month')
plt.ylabel('Average Occupancy Rate')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
users_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27562 entries, 0 to 27561
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PreferredSponsors  27562 non-null  object
#  1   Gender             18027 non-null  object
#  2   Country            27500 non-null  object
#  3   Degree             16750 non-null  object
#  4   Sign Up Date       27562 non-null  object
#  5   city               18029 non-null  object
#  6   zip                18027 non-null  object
#  7   isFromSocialMedia  27553 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 1.7+ MB

# %%
users_data_df.describe()
# Out:
#        isFromSocialMedia
# count       27553.000000
# mean            0.501252
# std             0.500008
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             1.000000
# max             1.000000

# %%
missing_value_count = users_data_df.isnull().sum()

# %%
missing_value_count
# Out:
# PreferredSponsors        0
# Gender                9535
# Country                 62
# Degree               10812
# Sign Up Date             0
# city                  9533
# zip                   9535
# isFromSocialMedia        9
# dtype: int64

# %%
users_data_df.shape
# Out:
# (27562, 8)

# %%
total_cells_missing_user = np.product(users_data_df.shape)
total_missing = missing_value_count.sum()
total_missing
# Out:
# 39486

# %%
percent_of_missing_values = (total_missing/total_cells_missing_user) * 100
print(percent_of_missing_values)
# Out:
# 17.907807851389595
